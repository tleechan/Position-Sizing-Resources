# %% [markdown]
# # Notebook Instructions
#
# 1. If you are new to Jupyter notebooks, please go through this introductory manual <a href='https://quantra.quantinsti.com/quantra-notebook' target="_blank">here</a>.
# 1. Any changes made in this notebook would be lost after you close the browser window. **You can download the notebook to save your work on your PC.**
# 1. Before running this notebook on your local PC:<br>
# i.  You need to set up a Python environment and the relevant packages on your local PC. To do so, go through the section on "**Run Codes Locally on Your Machine**" in the course.<br>
# ii. You need to **download the zip file available in the last unit** of this course. The zip file contains the data files and/or python modules that might be required to run this notebook.

# %% [markdown]
# # Implementation of CPPI
#
# CPPI is a position sizing strategy that enables an investor to enjoy the upside potential of a risky asset while hedging the exposure to downside risk. We use a multiplier to dynamically change the weight to protect downside risk. We lever the returns from the risky asset, with a multiple `m`. The balance portfolio serves as the floor value (or the minimum account value). To remove complexity, we will take the safe asset as cash.
#
# After completing this notebook, you will be able to implement the CPPI position sizing strategy in Python.
#
# You will perform the following steps:
#
# 1. [Read the Data](#read)
# 2. [Setting Portfolio Value, Multiplier Value, Floor Value](#portfolio_val)
# 3. [CPPI Logic](#strategy_logic)
# 4. [Portion of Capital](#portion)
# 5. [Leverage Ratio](#leverage)
#
# ## Import Libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Quantra function to analyse the performance
import sys
sys.path.append("..")
from data_modules.position_sizing_quantra import performance_analysis, plot_leverage, plot_portion_of_capital

# Import matplotlib and set the style
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')

# Ignore warnings
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id='read'></a>
# ## Read the Data
#
# The index reversal strategy's trading signal, returns and portfolio value are read from a file named `strategy_data.csv`.

# %%
strategy_df = pd.read_csv('../data_modules/strategy_data.csv',
                          index_col=0, parse_dates=True)
strategy_df.head()
# Out:
#             signal   returns  cumulative_returns
# 2005-01-03       0 -0.000000            1.000000
# 2005-01-04       1 -0.000000            1.000000
# 2005-01-05       1 -0.003537            0.996463
# 2005-01-06       0  0.003296            0.999747
# 2005-01-07       0 -0.000000            0.999747

# %% [markdown]
# <a id='portfolio_val'></a>
# ## Setting Portfolio Value, Multiplier Value, Floor Value
#
# 1. We will define the initial portfolio value as $$ \text{Initial portfolio value = 10000}$$
# 2. We will define the multiplier $$\text{Multiplier = 4}$$ Multiplier can be defined as a function of past drawdowns of the index returns. So, if index has shown a drawdown of 25%, we use $$Multiplier = \frac{1}{Drawdown} = 4$$
# 3. We set a floor percentage level, $$\text{Floor percent = 0.60}$$

# %%
# Setting initial portfolio value
initial_portfolio_value = 10000

# Setting multiplier value
m = 4

# Setting floor value
floor_percent = 0.9

print("Initial portfolio value value: ", initial_portfolio_value)
print("Multiplier value: ", m)
print("Floor percentage: ", floor_percent * 100, "%")
# Out:
# Initial portfolio value value:  10000
# Multiplier value:  4
# Floor percentage:  90.0 %

# %% [markdown]
# <a id='strategy_logic'></a>
# ## CPPI Logic
#
# The following steps are used for the CPPI Logic:
# 1. Define the cushion percentage as $$\text{Cushion percentage = 1 - Floor percentage}$$
# 2. Calculate floor and cushion values.
# 3. Calculate levered return as $$\text{Levered return = Multiplier * Return from risky asset}$$
# 4. Update account value as $$\text{Account value = Floor value + Cushion value * (1 + Levered return)}$$
# 5. Update cushion value as $$\text{Cushion = Account value - Floor value}$$

# %%
def run_cppi(risky_r, m, initial_capital, floor_percent, signals):
    # Set up CPPI parameters
    cushion_percentage = 1 - floor_percent

    # Absolute values
    floor = floor_percent * initial_capital
    cushion = cushion_percentage * initial_capital

    # Create dataframes for intermediate values
    account_history = pd.DataFrame([np.nan for _ in range(
        len(risky_r.index))], index=risky_r.index, columns=['account_history'])
    leverage_history = pd.DataFrame([np.nan for _ in range(
        len(risky_r.index))], index=risky_r.index, columns=['leverage_history'])
    capital_used = pd.DataFrame([np.nan for _ in range(
        len(risky_r.index))], index=risky_r.index, columns=['capital_used'])

    # Intialise variables
    account_value = initial_capital
    cap_used = 0

    # Run CPPI
    for row in range(len(risky_r)):
        # The risky asset returns will be multiplied by `m`
        levered_return = (m * risky_r.iloc[row])

        # Update account value and append to DF
        account_value = floor + (cushion * (1 + levered_return))
        account_history["account_history"].iloc[row] = account_value

        # Recalculate cushion
        cushion = account_value - floor

        # Update leverage and append to DF
        leverage = m * (cushion / account_value)
        leverage_history["leverage_history"].iloc[row] = leverage

        # Calculate capital used and append to DF
        cap_used = leverage * account_value
        capital_used["capital_used"].iloc[row] = cap_used

    # Update leverage and capital based on signals only for trading days
    leverage_history["leverage_history"] = leverage_history["leverage_history"] * \
        signals
    capital_used["capital_used"] = capital_used["capital_used"] * \
        signals

    return {
        'account_history': account_history,
        'leverage_history': leverage_history,
        'capital_used': capital_used
    }

# %% [markdown]
# #### Run the Strategy and Analyse Performance

# %%
# Run strategy with CPPI
strategy = run_cppi(strategy_df['returns'], m, initial_portfolio_value, floor_percent, strategy_df['signal'])

# CPPI strategy returns and converting to float
strategy_with_cppi = strategy['account_history']['account_history']

# Calculate benchmark returns (Strategy without CPPI)
benchmark_returns = initial_portfolio_value * (1 + strategy_df['returns']).cumprod()

# Plot performance analysis
performance_analysis(strategy_with_cppi, benchmark_returns)
# Out:
# Total returns: 305.31%
# Annualised returns (CAGR): 9.14%
# Maximum drawdown (MDD): -30.65%
# Return-to-MDD ratio: 0.3

# %% [markdown]
# <a id='portion'></a>
# ## Portion of Capital
# The plot shows the total wealth used in each trade which was calculated in `run_cppi`.

# %%
plot_portion_of_capital(strategy['capital_used'], strategy['account_history'])

# %% [markdown]
# Through the years as our account grows, we need more and more capital to deploy the strategy. We use leverage to finance this growth. For simplicity, we have not included the cost of leverage in our analysis. However, given the amount of leverage being deployed, it will form a significant portion of costs, reducing the total returns.

# %% [markdown]
# <a id='leverage'></a>
# ## Leverage Plot
# The leverage plot shows the amount used over and above the actual account value.

# %%
plot_leverage(strategy["leverage_history"])

# %% [markdown]
# We can see that as the years' progress, we use more and more leverage. This happens since as the strategy starts making profits, the cushion value increases. An increase in cushion value increases the amount allocated to the risky asset.
#
# In the upcoming unit, we will discuss the Time Invariant Portfolio Protection (TIPP). <br><br>
